# %% [markdown]
# <h1> Outils et écosystème de la science des données

# %% [markdown]
# **Objectifs:**
# <ul>
#     <li>Enumérer 3 (ou plus) bibliothèques couramment utilisées en science des données.</li>
#     <li>Indiquer trois outils open source d’environnement de développement utilisés en science des données</li>
#     <li>Lister les langages populaires pour la science des données</li>
#     <li>Ecrivez une expression qui convertit 200 minutes en heures</li>
#     <li>Evaluez l’expression (3*4)+5</li>
# </ul>

# %% [markdown]
# Dans ce notebook, les outils et l'écosystème de la science des données sont résumés.

# %% [markdown]
# Certains des langages populaires que les scientifiques des données utilisent sont :
# <ol><li>Python</li>
# <li>R</li>
# <li>Julia</li>

# %% [markdown]
# Certaines des bibliothèques couramment utilisées par les scientifiques des données incluent :
# <ol>
#     <li>Numpy</li>
#     <li>Scikit-Learn</li>
#     <li>TensorFlow</li>
#     <li>Pandas</li>
#     <li>ggplot</li>
#     <li>Matplotlib</li>
# </ol>

# %% [markdown]
# | Outils de la science des données |
# |-----------------------------------|
# | Jupyter Notebook                 |
# | RStudio                           |
# | Apache Zeppelin                   |

# %% [markdown]
# ### Voici quelques exemples d'évaluation d'expressions arithmétiques en Python
#
# - **Addition :** `5 + 3 = 8`
# - **Soustraction :** `10 - 4 = 6`
# - **Multiplication :** `7 * 2 = 14`
# - **Division :** `9 / 3 = 3.0`
# - **Exponentiation :** `2 ** 3 = 8`
# - **Modulo (reste de division) :** `10 % 3 = 1`

# %% [markdown]
# Ceci est une simple expression arithmétique pour multiplier puis additionner des entiers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# Cela convertira 200 minutes en heures en divisant par 60

# %%
minutes = 200
heures = minutes / 60
heures
# Out:
# 3.3333333333333335

# %% [markdown]
# <h2>Auteur</h2>
# NOUKON Gilberto Charbel Kayodé
